# %%
import pandas as pd
import numpy as np
import gzip
import os

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns


from collections import defaultdict #data colector

#Surprise: https://surprise.readthedocs.io/en/stable/
import surprise

from surprise.reader import Reader
from surprise import Dataset
from surprise.model_selection import GridSearchCV

  ##CrossValidation
from surprise.model_selection import cross_validate


  ##Matrix Factorization Algorithms
from surprise import SVD

# %%
data_dir = os.path.join('/Users/jiristodulka/GoogleDrive/GitHub/product_filter','data')

# %%
ratings = pd.read_csv(data_dir + '/ratings_sample.csv')

# %%
ratings.columns
# Out:
# Index(['reviewerID', 'title', 'overall'], dtype='object')

# %%
reader = Reader(rating_scale=(1, 5)) #line_format by default order of the fields
data = Dataset.load_from_df(ratings[["reviewerID","title","overall"]], reader=reader)

# %%
trainset = data.build_full_trainset()

testset = trainset.build_anti_testset()

# %%
pd.read_csv(data_dir + '/sampled_reviews.csv')
# Out:
#         overall  verified   reviewTime      reviewerID        asin  \
# 0           5.0     False  06 19, 2000   A9L3BUKDG2XNM  B000068MBW
# 1           5.0      True   08 6, 2014  A3HSCQNZJ05ZTB  B000068MBW
# 2           5.0      True   12 2, 2014  A1PK7MKN0133ML  B000068MBW
# 3           5.0     False  01 19, 2010   A4PPZNQF1X2IY  B000068MBW
# 4           3.0     False  08 30, 2010  A352V92Q09UZC9  B000068MBW
# ...         ...       ...          ...             ...         ...
# 134365      2.0     False   12 3, 2004   A51A2THXMB87L  B00009RG46
# 134366      4.0     False  05 28, 2006  A3I6E516DU4VOF  B00009RG46
# 134367      5.0     False  12 22, 2007  A1Y0BFFXAK11HJ  B00009RG46
# 134368      5.0      True   07 8, 2009  A1BLGPUF4AE0EJ  B00009RG46
# 134369      5.0     False   09 6, 2005  A1AJA930WZO14R  B00009RG46
#
#                            style     reviewerName  \
# 0       {'Format:': ' VHS Tape'}  Amazon Customer
# 1            {'Format:': ' DVD'}  Amazon Customer
# ...
